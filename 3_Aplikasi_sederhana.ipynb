# %% [markdown]
# <a href="https://colab.research.google.com/github/syarifahdanis1-gif/KKA-X-Semester-1/blob/main/3_Aplikasi_sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Danis syarifah
#
# Kelas: X-11
#
# No.absen : 10
#
#
# Nama kelompok:Panda imoet

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume bola

# %%
jari_jari = int(input("Masukkan jari-jari dari bola (cm): "))
pi = 22/7
Volume_bola = 4/3 * pi * jari_jari**3
print(f"Volume bola adalah {Volume_bola} cm^3. ")
# Out:
# Masukkan jari-jari dari bola (cm): 7
# Volume bola adalah 1437.333333333333 cm^3.

# %%
jari_jari = int(input("Masukkan jari-jari dari kerucut (cm): "))
tinggi = int(input("Masukkan tinggi dari kerucut (cm): "))
pi = 22/7
Volume_kerucut = 1/3 * pi * jari_jari **2*tinggi
print(f" Volume kerucut adalah {Volume_kerucut}cm^2")
# Out:
# Masukkan jari-jari dari kerucut (cm): 4
# Masukkan tinggi dari kerucut (cm): 8
#  Volume kerucut adalah 134.09523809523807cm^2
