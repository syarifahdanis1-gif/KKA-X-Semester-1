# %% [markdown]
# <a href="https://colab.research.google.com/github/syarifahdanis1-gif/KKA-X-Semester-1/blob/main/Fungsi_prinst_Danis_x_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Danis syarifah
#
# Kelas : x. 11
#
# No. Absen : 10

# %% [markdown]
# #Menampilkan Teks bebas

# %%
print("Danis syarifah")
# Out:
# Danis syarifah

# %% [markdown]
# #Menampilkan Nilai variabel

# %%
nama_saudara = "hanum karimau "

print(nama_saudara)
# Out:
# hanum karimau

# %%
jumlah_saudara = 3

print(jumlah_saudara)
# Out:
# 3

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Koma

# %%
print("saya memiliki saudara sebanyak", jumlah_saudara, "Nama saudara saya adalah", nama_saudara)
# Out:
# saya memiliki saudara sebanyak 3 Nama saudara saya adalah hanum karima

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda plus

# %%
print("Saya memiliki saudara sebanyak " + str(jumlah_saudara) + ". " + "Nama saudara saya adalah " + nama_saudara + ".")
# Out:
# Saya memiliki saudara sebanyak 3. Nama saudara saya adalah hanum karimau .

# %% [markdown]
# ##Menampilkan Teks bebas dan Nilai Variabel Menggunakan f string

# %%
print(f"saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")

# %% [markdown]
# ##Escape Character

# %%
print("Nama : Danis syarifah")
print("Kelas: x-11")
print("No.absen : 10")
# Out:
# Nama : Danis syarifah
# Kelas: x-11
# No.absen : 10

# %%
print("Nama : Danis syarifah \nKelas : x-11\nNo.absen : 10")
# Out:
# Nama : Danis syarifah
# Kelas : x-11
# No.absen : 10

# %%
print("""Nama\t\t: Danis Syarifah
kelas\t\t: X -11
No. absen\t: 10""")
# Out:
# Nama		: Danis Syarifah
# kelas		: X -11
# No. absen	: 10

# %%
print("Danis syarifah")
# Out:
# Danis syarifah

# %%
print('Danis syarifah')
# Out:
# Danis syarifah

# %%
print('Habib ja\'far')
# Out:
# Habib ja'far

# %%
print('Bu shinta berkata : "Harap fokus menyimak".')
# Out:
# Bu shinta berkata : "Harap fokus menyimak".

# %%
print("Bu shinta berkata :\"Harap fokus menyimak\".")
# Out:
# Bu shinta berkata :"Harap fokus menyimak".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\Man Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\Man Demak\KKA\Tugas
