# %% [markdown]
# <a href="https://colab.research.google.com/github/syarifahdanis1-gif/KKA-X-Semester-1/blob/main/2_Tipe_variabel_Danis_s_x_11_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Danis syarifah
#
# Kelas : x - 11
#
# No. absen: 10

# %%
print("Danissyarifah.2025@gmail.com")
print("Danissyarifah.2025@gmail.com")
print("Danissyarifah.2025@gmail.com")
# Out:
# Danissyarifah.2025@gmail.com
# Danissyarifah.2025@gmail.com
# Danissyarifah.2025@gmail.com

# %%
email_uster_1 = "Danissyarifahh.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# Danissyarifahh.2025@gmail.com
# Danissyarifahh.2025@gmail.com
# Danissyarifahh.2025@gmail.com

# %% [markdown]
# #Peraturan penamaan variabel

# %%
#Hanya diperbolehlan menggunakan huruf, angka dan underscore
email user 2 = "Danissyarifah@gmail.com"

print("email user 2 ")
# Out:
#   File "/tmp/ipython-input-2907277780.py", line 2
#     email user 2 = "Danissyarifah@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
Emailuser2 = "Danissyarifah@gmail.com"

print(Emailuser2)
# Out:
# Danissyarifah@gmail.com

# %%
#Tidak boleh didahului angka

3_email_user = "Danissyarifah@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-1506891818.py", line 3
#     3_email_user = "Danissyarifah@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "Danissyarifah@gmail.com"

print(email_user_3)
# Out:
# Danissyarifah@gmail.com

# %%
#Tidak boleh memggunakan kata kunci python
for = "Danissyarifah@gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-1214240707.py", line 2
#     for = "Danissyarifah@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Danissyarifah@gmail.com"

print(For)
# Out:
# Danissyarifah@gmail.com

# %%
Print = "Danissyarifah@gmail.com"

# %%
print = Danisyarifah@gmail.com"


print(print)
# Out:
#   File "/tmp/ipython-input-3333117821.py", line 1
#     print = Danissyarifah@gmail.com"
#                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
Print = "Danissyarifah@gmail.com"

print(Print)
# Out:
# Danissyarifah@gmail.com

# %%
#Tidak eror tapi dianjurkan harus deskiptif

_ = "Danissyarifah@gmail.com"

# %%
print(_)
# Out:
# Danissyarifah@gmail.com

# %%
_ = "Hanumkarima@gmail.com"

# %%
print(_)
# Out:
# Hanumkarima@gmail.com

# %% [markdown]
# #Assighmen

# %%
Single assignment
nama_mahasiswa_1 = "Alexandrio"

print(nama_mahasiswa_1)
# Out:
#   File "/tmp/ipython-input-1695806772.py", line 1
#     Single assignment
#            ^
# SyntaxError: invalid syntax

# %%
#Multiple assignment

# nama_barang_1 = "rinso"
# nama_barang_2 = "molto"

nama_barang_1, nama_barang_2 = "rinso", " molto"

print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
#  molto

# %%
#Assignment yang sama
nilai_Danis = nilai_hanum = nilai_ana = 100

print(nilai_Danis)
print(nilai_hanum)
print(nilai_ana)
# Out:
# 100
# 100
# 100

# %%
#Menimpa/mengubah nilai variabel
nilai_fathin = 95

# %%
print(nilai_fathin)
# Out:
# 95

# %%
nilai_fathin = 100

# %%
print(nilai_fathin)
# Out:
# 95

# %% [markdown]
# #Operator aritmatika

# %%
buku_tulis_danis = 55
buku_tulis_hanum = 15

# %%
#penjumlahan
total_buku_tulis = buku_tulis_danis + buku_tulis_hanum
print(total_buku_tulis)
# Out:
# 70

# %%
#pengurangan
selisih_buku_tulis = buku_tulis_danis - buku_tulis_hanum
print(selisih_buku_)

# %% [markdown]
# #Tipe variabel

# %%
usia = 8
print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
nama = "Danis"
type(nama)
# Out:
# str

# %%
lulus = True
type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = 10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #konverensi Tipe data

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1

print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool
